# %% [markdown]
# # 라이브러리 가져오기

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 지도 시각화 때 사용할 라이브러리
import folium

# %% [markdown]
# # 데이터 불러오기

# %%
covid_filepath = "/content/drive/MyDrive/ICT-COG/02. 데이터 분석/Ch 05. Data analyze/3. Global  COVID-19 데이터 분석하기/data/covid_19_clean_complete.csv"

corona = pd.read_csv(covid_filepath)
corona.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c9a72e87964e> in <module>()
#       1 covid_filepath = "/content/drive/MyDrive/ICT-COG/02. 데이터 분석/Ch 05. Data analyze/3. Global  COVID-19 데이터 분석하기/data/covid_19_clean_complete.csv"
#       2
# ----> 3 corona = pd.read_csv(covid_filepath)
#       4 corona.head()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    2008         kwds["usecols"] = self.usecols
#    2009
# -> 2010         self._reader = parsers.TextReader(src, **kwds)
#    2011         self.unnamed_cols = self._reader.unnamed_cols
#    2012
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/ICT-COG/02. 데이터 분석/Ch 05. Data analyze/3. Global  COVID-19 데이터 분석하기/data/covid_19_clean_complete.csv'

# %% [markdown]
# # 데이터 확인 하기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 결측값 확인하기

# %%
corona.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# ## 정보 확인하기

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ## 데이터 타입 수정하기
# * 문자열로 되어 있는 `Date`를 날짜 자료형 `Datetime`으로 바꾸기

# %%
corona['Date'] = pd.to_datetime(corona['Date'])
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# # 코로나 바이러스의 국가별 최신 확진자, 사망자, 회복자 데이터 분석

# %% [markdown]
# ## 최근 데이터만 남기기

# %%
corona_lt = corona[corona['Date'] == max(corona['Date'])]
corona_lt.head()
# Out:
#       Province/State Country/Region  ...  Active             WHO Region
# 48807            NaN    Afghanistan  ...    9796  Eastern Mediterranean
# 48808            NaN        Albania  ...    1991                 Europe
# 48809            NaN        Algeria  ...    7973                 Africa
# 48810            NaN        Andorra  ...      52                 Europe
# 48811            NaN         Angola  ...     667                 Africa
#
# [5 rows x 10 columns]

# %% [markdown]
# ## 국가별 합계 구하기

# %%
corona_lt_country_sum = corona_lt.groupby("Country/Region")["Confirmed", "Deaths", "Recovered"].sum() # 합계를 구하는건 여기서는 별 의미가 없음...
corona_lt_country_sum.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                 Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan         36263    1269      25198
# Albania              4880     144       2745
# Algeria             27973    1163      18837
# Andorra               907      52        803
# Angola                950      41        242

# %%
corona_lt_country_sum = corona_lt_country_sum.reset_index()
corona_lt_country_sum
# Out:
#          Country/Region  Confirmed  Deaths  Recovered
# 0           Afghanistan      36263    1269      25198
# 1               Albania       4880     144       2745
# 2               Algeria      27973    1163      18837
# 3               Andorra        907      52        803
# 4                Angola        950      41        242
# ..                  ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752
# 183      Western Sahara         10       1          8
# 184               Yemen       1691     483        833
# 185              Zambia       4552     140       2815
# 186            Zimbabwe       2704      36        542
#
# [187 rows x 4 columns]

# %% [markdown]
# ## 사망자가 많은 순으로 정렬

# %%
corona_deaths_sorted = corona_lt_country_sum.sort_values(by="Confirmed", ascending=False)
corona_deaths_sorted
# Out:
#             Country/Region  Confirmed  Deaths  Recovered
# 173                     US    4290259  148011    1325804
# 23                  Brazil    2442375   87618    1846641
# 79                   India    1480073   33408     951166
# 138                 Russia     816680   13334     602249
# 154           South Africa     452529    7067     274925
# ..                     ...        ...     ...        ...
# 49                Dominica         18       0         18
# 140  Saint Kitts and Nevis         17       0         15
# 68               Greenland         14       0         13
# 75                Holy See         12       0         12
# 183         Western Sahara         10       1          8
#
# [187 rows x 4 columns]

# %% [markdown]
# ### 데이터 프레임상에서 모든 데이터를 보여줌과 동시에 히트맵 처럼 표시 - 잔기술

# %%
corona_deaths_sorted.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row0_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row0_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row1_col3{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row0_col3{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row1_col1{
#             background-color:  #f4503a;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row1_col2{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row2_col1{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row2_col2{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row2_col3{
#             background-color:  #fa6547;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row3_col1{
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row3_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row5_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row6_col1{
#             background-color:  #fee6da;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row3_col3{
#             background-color:  #fca285;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row4_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row9_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row14_col3{
#             background-color:  #fee3d7;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row4_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row18_col1{
#             background-color:  #ffede5;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row4_col3{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row5_col2{
#             background-color:  #fcab8f;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row5_col3{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row6_col2{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row6_col3{
#             background-color:  #fedaca;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row7_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row11_col3{
#             background-color:  #fee8dd;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row7_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row13_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row13_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row18_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row20_col2{
#             background-color:  #ffebe2;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row7_col3{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row8_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row13_col3{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row8_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row8_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row20_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row22_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row29_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row30_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row32_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row35_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row37_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row39_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row40_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row41_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row47_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row48_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row52_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row55_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row58_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row58_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row60_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row61_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row63_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row64_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row65_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row66_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row66_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row67_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row67_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row67_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row68_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row68_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row69_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row69_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row70_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row70_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row71_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row71_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row72_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row72_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row72_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row73_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row73_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row74_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row75_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row75_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row76_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row76_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row76_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row77_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row77_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row77_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row78_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row78_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row78_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row79_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row79_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row79_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row80_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row80_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row80_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row81_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row81_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row81_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row82_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row82_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row83_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row83_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row84_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row84_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row84_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row85_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row85_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row85_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row86_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row86_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row86_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row87_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row87_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row87_col3,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row88_col1,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row88_col2,#T_5d17fc0a_cbee_11eb_bd93_0242ac1c0002row ...

# %% [markdown]
# # 시간에 따른 확진자, 사망자, 회복자 시각화

# %% [markdown]
# ## 날짜별 확진자, 사망자, 회복자 합계 구하기

# %%
corona_date = corona.groupby("Date")["Confirmed", "Deaths", "Recovered"].sum()
corona_date.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        555      17         28
# 2020-01-23        654      18         30
# 2020-01-24        941      26         36
# 2020-01-25       1434      42         39
# 2020-01-26       2118      56         52

# %% [markdown]
# Date가 순서대로 안되어있을 가능성도 있으니까 인덱스를 재정렬

# %%
corona_date = corona_date.sort_index()
corona_date.head()
# Out:
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        555      17         28
# 2020-01-23        654      18         30
# 2020-01-24        941      26         36
# 2020-01-25       1434      42         39
# 2020-01-26       2118      56         52

# %% [markdown]
# ## 시간에 따른 누적 확진자, 사망자, 회복자 그래프 그리기

# %%
plt.figure(figsize=(22, 10))
plt.xticks(rotation=45)
sns.lineplot(data=corona_date)
plt.show()

# %% [markdown]
# # 전세계 코로나 바이러스 감염 지도

# %% [markdown]
# ## folium 사용방법 이해

# %%
import folium

map = folium.Map()
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7395947581224f899b0fe6e7f9d88be3%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7395947581224f899b0fe6e7f9d88be3%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7395947581224f899b0fe6e7f9d88be3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7395947581224f899b0fe6e7f9d88be3%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%201%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_43637fe02b57498fb932f1c9279d1cd9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22detect ...

# %% [markdown]
# ## folium으로 서울 표시하기

# %%
map = folium.Map(location=[37.5642135, 127.0016985])
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_b09dc540051f4c32b26cbc65e27c9870%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b09dc540051f4c32b26cbc65e27c9870%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_b09dc540051f4c32b26cbc65e27c9870%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_b09dc540051f4c32b26cbc65e27c9870%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.5642135%2C%20127.0016985%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_9049eb71bff54776aff910215d763d90%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# ### 확대하기

# %%
map = folium.Map(location=[37.5642135, 127.0016985], zoom_start=12)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_9f61124c93304c48815954c47bb83639%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_9f61124c93304c48815954c47bb83639%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_9f61124c93304c48815954c47bb83639%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_9f61124c93304c48815954c47bb83639%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.5642135%2C%20127.0016985%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2012%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_bc5e32963d4b465bafa746d668f7d142%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# ## CircleMarker 그리기

# %%
map = folium.Map(location=[37.5642135, 127.0016985], zoom_start=16)

# 서울 시청 좌표
seoul_cityhall_coord = [37.565577, 126.978082]

folium.CircleMarker(seoul_cityhall_coord, radius=100).add_to(map) # 원을 그려서 맵에 추가하겠다.

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_7df8b585d5324360bbe4263249b0668d%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7df8b585d5324360bbe4263249b0668d%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_7df8b585d5324360bbe4263249b0668d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_7df8b585d5324360bbe4263249b0668d%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.5642135%2C%20127.0016985%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2016%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6f8046e9ff6b47e8809ca0a9adca4506%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# ### CircleMarker 색상, 채우기, 원 내부 색상 설정

# %%
seoul_cityhall_coord = [37.565577, 126.978082]
map = folium.Map(location=seoul_cityhall_coord, zoom_start=16)

folium.CircleMarker(seoul_cityhall_coord, radius=100, color="#F7D358", fill=True, fill_color="#08088A").add_to(map) # 원을 그려서 맵에 추가하겠다.

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_30df55c811c74d3e8a8c027da4e77ab0%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_30df55c811c74d3e8a8c027da4e77ab0%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_30df55c811c74d3e8a8c027da4e77ab0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_30df55c811c74d3e8a8c027da4e77ab0%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.565577%2C%20126.978082%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2016%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_dcdacab998f94de89dc4d9c8ca12281d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# ### CircleMarker의 팝업 설정

# %%
seoul_cityhall_coord = [37.565577, 126.978082]
map = folium.Map(location=seoul_cityhall_coord, zoom_start=16)

folium.CircleMarker(seoul_cityhall_coord, radius=100, color="#F7D358", fill=True, fill_color="#08088A", popup="여기는 시청입니다!").add_to(map) # 원을 그려서 맵에 추가하겠다.

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_a1ed9b9d31d24b1bb2b928b0f49e9dff%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a1ed9b9d31d24b1bb2b928b0f49e9dff%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_a1ed9b9d31d24b1bb2b928b0f49e9dff%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_a1ed9b9d31d24b1bb2b928b0f49e9dff%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B37.565577%2C%20126.978082%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2016%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6e9b6f0cdf0c4519bb39a782cff44fc9%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20 ...

# %% [markdown]
# # 전세계 코로나 바이러스 감염 지도 표시

# %%
# 국가별 최신 확진자 조회
corona_lt.head()
# Out:
#       Province/State Country/Region  ...  Active             WHO Region
# 48807            NaN    Afghanistan  ...    9796  Eastern Mediterranean
# 48808            NaN        Albania  ...    1991                 Europe
# 48809            NaN        Algeria  ...    7973                 Africa
# 48810            NaN        Andorra  ...      52                 Europe
# 48811            NaN         Angola  ...     667                 Africa
#
# [5 rows x 10 columns]

# %%
import numpy as np
map = folium.Map(location=[0, 0], zoom_start=3)

for n in corona_lt.index:
  # 위경도 가져오기
  coords = [ corona_lt['Lat'][n], corona_lt["Long"][n]]
  radius = int(np.log(corona_lt['Confirmed'][n])) * 2
  popup_str = f"{ corona_lt['Country/Region'][n] } / { corona_lt['Confirmed'][n]}"
  
  folium.CircleMarker(
      coords, radius=radius, popup=popup_str, color='red', fill=True, fill_color='red'
  ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_b4913fb075f9435085eee786f9cc1714%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b4913fb075f9435085eee786f9cc1714%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_b4913fb075f9435085eee786f9cc1714%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_b4913fb075f9435085eee786f9cc1714%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%203%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_0bae1031eb8d445d9ad7520a60fe039d%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20%20%20%20%20%22detect ...
